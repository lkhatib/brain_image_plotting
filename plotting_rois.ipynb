# %%
from nilearn import plotting
from nilearn import datasets

# %%
dataset_ho = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')

# %%
plotting.plot_roi('/Volumes/MRI/mfc/derivatives/dep_lk/seed/vmpfc_difumo.nii.gz', bg_img='/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz',)

# %%
plotting.plot_stat_map('/Volumes/MRI/mfc/derivatives/dep_lk/group/rest_only/med_vs_control/randomise_bi_amygdala/ICAclean_flame1_2.3_bilateral_amygdala_V1V6res_dep_interaction.gfeat_61_vmpfc_tfce_corrp_tstat2.nii.gz',
                      threshold=0.95, cmap = 'Blues')
